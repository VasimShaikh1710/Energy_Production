# %%
import pandas as pd

# %%
df = pd.read_csv("energy_production.csv")
df
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9568.000000     9568.000000   9568.000000  9568.000000
# mean     19.651231       54.305804   1013.259078    73.308978
# std       7.452473       12.707893      5.938784    14.600269
# min       1.810000       25.360000    992.890000    25.560000
# 25%      13.510000       41.740000   1009.100000    63.327500
# 50%      20.345000       52.080000   1012.940000    74.975000
# 75%      25.720000       66.540000   1017.260000    84.830000
# max      37.110000       81.560000   1033.300000   100.160000
#
#        energy_production
# count        9568.000000
# mean          454.365009
# std            17.066995
# min           420.260000
# 25%           439.750000
# 50%           451.550000
# 75%           468.430000
# max           495.760000

# %%
correlation = df.corr()
correlation
# Out:
#                    temperature  exhaust_vacuum  amb_pressure  r_humidity  \
# temperature           1.000000        0.844107     -0.507549   -0.542535
# exhaust_vacuum        0.844107        1.000000     -0.413502   -0.312187
# amb_pressure         -0.507549       -0.413502      1.000000    0.099574
# r_humidity           -0.542535       -0.312187      0.099574    1.000000
# energy_production    -0.948128       -0.869780      0.518429    0.389794
#
#                    energy_production
# temperature                -0.948128
# exhaust_vacuum             -0.869780
# amb_pressure                0.518429
# r_humidity                  0.389794
# energy_production           1.000000

# %% [markdown]
# # Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)

plt.title('Correlation Heatmap using Seaborn')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x= df['temperature'], y= df['energy_production'])

plt.xlabel('temperature')
plt.ylabel('energy_production')
plt.title('Scatter Plot of temperature vs. energy_production')
plt.show()

# %%
sns.scatterplot(x= df['exhaust_vacuum'], y= df['energy_production'])

plt.xlabel('exhaust_vacuum')
plt.ylabel('energy_production')
plt.title('Scatter Plot of exhaust_vacuum vs. energy_production')
plt.show()

# %%
sns.scatterplot(x= df['amb_pressure'], y= df['energy_production'])

plt.xlabel('amb_pressure')
plt.ylabel('energy_production')
plt.title('Scatter Plot of amb_pressure vs. energy_production')
plt.show()

# %%
sns.scatterplot(x= df['r_humidity'], y= df['energy_production'])

plt.xlabel('r_humidity')
plt.ylabel('energy_production')
plt.title('Scatter Plot of r_humidity vs. energy_production')
plt.show()

# %% [markdown]
# # Histogram

# %%
sns.distplot(df['temperature'], label='temperature',bins = 10)

plt.xlabel('Values of temperature')
plt.ylabel('Frequency')
plt.legend()
plt.title('Histogram of temperature')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['exhaust_vacuum'], label='exhaust_vacuum',bins = 10)

plt.xlabel('Values of exhaust_vacuum')
plt.ylabel('Frequency')
plt.legend()
plt.title('Histogram of exhaust_vacuum')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['amb_pressure'], label='amb_pressure',bins = 10)

plt.xlabel('Values of amb_pressure')
plt.ylabel('Frequency')
plt.legend()
plt.title('Histogram of amb_pressure')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['r_humidity'], label='r_humidity',bins = 10)

plt.xlabel('Values of r_humidity')
plt.ylabel('Frequency')
plt.legend()
plt.title('Histogram of r_humidity')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # distplot

# %%
from scipy.stats import norm

# %%
a = ['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity', 'energy_production']

for i in a:
    sns.distplot(df[i], hist = False, fit = norm)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Box Plot

# %%
df.boxplot(column = 'temperature', vert = False)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'exhaust_vacuum', vert = False)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'amb_pressure', vert = False)
# Out:
# <AxesSubplot:>

# %%
import numpy as np

# %%
aQ1 = np.percentile(df['amb_pressure'],25)
aQ3 = np.percentile(df['amb_pressure'], 75)

aIQR = aQ3 - aQ1

print(f"aQ1 = {aQ1}\naQ3 = {aQ3}\naIQR = {np.round(aIQR)}")
# Out:
# aQ1 = 1009.1
# aQ3 = 1017.26
# aIQR = 8.0

# %%
LW = aQ1 - (1.5*aIQR)
UW = aQ3 + (1.5*aIQR)

print(f"LW = {LW}\nUW = {UW}")
# Out:
# LW = 996.8600000000001
# UW = 1029.5

# %%
a1 = df[df["amb_pressure"] < LW]
a1
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 962         16.03           41.23        996.35       82.04             464.67
# 2792        14.84           41.23        995.02       88.00             464.85
# 3395        18.15           41.23        993.82       61.21             456.32
# 4200        10.67           42.02        996.55       99.94             472.65
# 4237        12.95           41.23        993.74       96.35             469.05
# 4785        13.83           41.23        993.31       93.94             466.20
# 5170        14.13           41.23        994.60       93.02             467.84
# 5292        11.01           42.02        995.24       98.62             473.96
# 5565        15.62           41.23        992.89       83.99             463.21
# 5890         3.26           41.31        996.32      100.00             489.38
# 6424        16.21           41.23        995.88       80.00             463.09
# ...

# %%
a2 = df[df["amb_pressure"] > UW]
a2
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 38           9.95           41.82       1033.09       69.44             477.52
# 175          9.06           41.92       1029.90       90.88             473.37
# 315         14.46           42.86       1031.34       69.84             464.44
# 319         14.58           41.92       1030.42       61.96             462.69
# 385         14.20           42.86       1031.96       69.59             468.63
# ...           ...             ...           ...         ...                ...
# 9093         9.42           41.40       1030.38       87.80             472.99
# 9125         7.66           41.92       1031.96       82.48             485.11
# 9331         5.97           36.25       1029.65       86.74             487.03
# 9368        14.31           42.86       1031.14       69.60             465.36
# 9501        12.02           41.92       1030.10       84.45             465.82
#
# [73 rows x 5 columns]

# %%
df.boxplot(column = 'r_humidity', vert = False)
# Out:
# <AxesSubplot:>

# %%
rQ1 = np.percentile(df['r_humidity'],25)
rQ3 = np.percentile(df['r_humidity'], 75)

rIQR = rQ3 - rQ1

print(f"rQ1 = {rQ1}\nrQ3 = {rQ3}\nrIQR = {np.round(rIQR)}")
# Out:
# rQ1 = 63.3275
# rQ3 = 84.83
# rIQR = 22.0

# %%
LW = Q1 - (1.5*IQR)
UW = Q3 + (1.5*IQR)

print(f"LW = {LW}\nUW = {UW}")
# Out:
# LW = 31.073750000000004
# UW = 117.08375

# %%
r1 = df[df["r_humidity"] < LW]
r1
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 30          33.94           74.67       1015.94       28.16             427.98
# 233         34.65           74.67       1016.03       26.67             427.69
# 400         35.01           74.67       1016.10       26.30             428.48
# 1154        34.30           74.67       1015.98       25.89             427.84
# 1254        19.78           44.71       1015.70       29.43             465.49
# 1814        19.31           44.71       1016.13       30.59             463.00
# 5610        29.85           68.24       1007.01       30.99             433.43
# 5674        33.83           67.90       1005.94       29.86             428.12
# 6048        34.18           67.90       1005.87       30.34             425.50
# 6214        19.32           44.71       1015.30       28.81             464.38
# 7287        18.76           44.71       1015.15       30.83             462.18
# ...

# %%
df[df["r_humidity"] > UW]
# Out:
# Empty DataFrame
# Columns: [temperature, exhaust_vacuum, amb_pressure, r_humidity, energy_production]
# Index: []

# %%
df.boxplot(column = 'energy_production', vert = False)
# Out:
# <AxesSubplot:>

# %%
out = pd.concat([a1,a2,r1])
out
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 962         16.03           41.23        996.35       82.04             464.67
# 2792        14.84           41.23        995.02       88.00             464.85
# 3395        18.15           41.23        993.82       61.21             456.32
# 4200        10.67           42.02        996.55       99.94             472.65
# 4237        12.95           41.23        993.74       96.35             469.05
# ...           ...             ...           ...         ...                ...
# 5674        33.83           67.90       1005.94       29.86             428.12
# 6048        34.18           67.90       1005.87       30.34             425.50
# 6214        19.32           44.71       1015.30       28.81             464.38
# 7287        18.76           44.71       1015.15       30.83             462.18
# 7936        34.24           74.67       1016.24       25.56             425.58
#
# [100 rows x 5 columns]

# %% [markdown]
# # check the prcentage of outliers

# %%
df.shape, out.shape
# Out:
# ((9568, 5), (100, 5))

# %%
import numpy as np

# %%
np.round((out.shape[0]/df.shape[0])*100)
# Out:
# 1.0

# %%
df.shape
# Out:
# (9568, 5)

# %%
df2 = df[df["amb_pressure"] > LW]
df2
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9553 rows x 5 columns]

# %%
df2 = df2[df2["amb_pressure"] < UW]
df2
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9480 rows x 5 columns]

# %%
df2 = df2[df2["r_humidity"] > LW]
df2
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9468 rows x 5 columns]

# %%
df2.to_csv("ene_prod.csv", index = False)

# %%
df = pd.read_csv("ene_prod.csv")
df
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9463        17.10           49.69       1005.53       81.82             457.32
# 9464        24.73           65.34       1015.42       52.80             446.92
# 9465        30.44           56.24       1005.19       56.24             429.34
# 9466        23.00           66.05       1020.61       80.29             421.57
# 9467        17.75           49.25       1020.86       63.67             454.41
#
# [9468 rows x 5 columns]
